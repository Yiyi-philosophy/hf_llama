# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data_ntk_2 = np.loadtxt(open("./ntk-2.csv", "rb"), delimiter = ',', skiprows = 0)
index = data_ntk_2[0, :]
data_ntk_2 = data_ntk_2[3, :]


data_ntk_4 = np.loadtxt(open("./ntk-4.csv", "rb"), delimiter = ',', skiprows = 0)
data_ntk_4 = data_ntk_4[3, :]

data_ntk_8 = np.loadtxt(open("./ntk-8.csv", "rb"), delimiter = ',', skiprows = 0)
data_ntk_8 = data_ntk_8[3, :]

data_ntk_16 = np.loadtxt(open("./ntk-16.csv", "rb"), delimiter = ',', skiprows = 0)
data_ntk_16 = data_ntk_16[3, :]

# %%
data_pi_2 = np.loadtxt(open("./pi-2.csv", "rb"), delimiter = ',', skiprows = 0)
data_pi_2 = data_pi_2[2, :]

data_pi_4 = np.loadtxt(open("./pi-4.csv", "rb"), delimiter = ',', skiprows = 0)
data_pi_4 = data_pi_4[2, :]

data_pi_8 = np.loadtxt(open("./pi-8.csv", "rb"), delimiter = ',', skiprows = 0)
data_pi_8 = data_pi_8[2, :]

# %%
data_standard = np.loadtxt(open("./standard-4.csv", "rb"), delimiter = ',', skiprows = 0)
data_standard = data_standard[1, :]

# %%
plt.xlabel("Seq Length")
plt.ylabel("PPL")

plt.xlim((100, 7000))
plt.ylim((1, 20))

# plt.plot(index, data_ntk_2, label="NTK-2")
# plt.plot(index, data_ntk_4, label="NTK-4")
# plt.plot(index, data_ntk_8, label="NTK-8")
# plt.plot(index, data_ntk_16, label="NTK-16")

plt.plot(index, data_pi_2, label="PI-2")
plt.plot(index, data_pi_4, label="PI-4")
plt.plot(index, data_pi_8, label="PI-8")

plt.plot(index, data_standard, label="Standard")

plt.legend()

# plt.savefig('./long_seq.jpg',  dpi=600)
# plt.show()

# %%
plt.xlim((100, 5000))
plt.ylim((1, 20))
plt.show()
